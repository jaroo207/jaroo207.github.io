# %%
# Import pandas and matplot lib

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 


# read csv file

df = pd.read_csv("S&P500.csv")

# %%
# data import test 

df_ops.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2016-02-01  1936.939941  1962.959961  1810.099976  1932.229980
# 1  2016-03-01  1937.089966  2072.209961  1937.089966  2059.739990
# 2  2016-04-01  2056.620117  2111.050049  2033.800049  2065.300049
# 3  2016-05-01  2067.169922  2103.479980  2025.910034  2096.949951
# 4  2016-06-01  2093.939941  2120.550049  1991.680054  2098.860107
#
#      Adj Close       Volume
# 0  1932.229980  93049560000
# 1  2059.739990  92639420000
# 2  2065.300049  81124990000
# 3  2096.949951  78883600000
# 4  2098.860107  86852700000

# %%
fig, ax = plt.subplots()
ax.plot(df['Date'],df['Adj Close'], label = 'S&P 500 Growth', color = 'b')


year = df['Date']
ax.set_xticks(year[:: 12])
# ax.set_xtick_labels(df['Month-Year']:: 50)

ax.xaxis.set_label_text ('Date', fontsize = '14')
ax.yaxis.set_label_text ('Adjusted Close Price', fontsize = '16')
ax.axvspan(47, 52, ymin = 0, ymax = 50000, facecolor = 'k', alpha = 0.1)



ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

fig.suptitle('5 Year S&P 500 Growth', fontsize = '20')



fig.set_size_inches(11, 8)
